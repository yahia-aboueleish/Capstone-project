# %% [markdown]
# # Import the needed libraries

# %%
import pandas as pd
import numpy as np 
import csv
from lxml import html
import urllib
import json
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Load the pages

# %%
page = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text
soup= BeautifulSoup(page,'lxml')

# !wget -q -O 'newyork_data.json' https://ibm.box.com/shared/static/fbpwbovar7lf8p5sgddm06cgipa2rxpe.json
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %% [markdown]
# # Find the table

# %%
postal = soup.find('table', class_='wikitable sortable')

# %% [markdown]
# # Convert to pandas dataframe

# %%
df = pd.read_html(str(postal))
dfs = df[0]
dfs.columns= ['Postcode','Borough','Neighborhood']
dfa=dfs.drop(dfs.index[0])

neighborhoods_data = newyork_data['features']
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %% [markdown]
# # Apply the conditions needed

# %%
dfw = dfa[dfa.Borough != 'Not assigned']
dfr=dfw.groupby(['Postcode','Borough'])['Neighborhood'].apply(lambda x: ','.join(x)).reset_index()
dfr['Neighborhood'] = np.where(dfr['Neighborhood'] == 'Not assigned', dfr['Borough'], dfr['Neighborhood'])
dfv = dfr

# %% [markdown]
# # Finish the dataframe

# %%
dfv.shape
dfn=pd.read_csv('http://cocl.us/Geospatial_data')
dfn.columns= ['Postcode','Latitude','Longitude']

# %% [markdown]
# # Combine both dataframes

# %%
dft=dfv.merge(dfn, how='left')
dft
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %% [markdown]
# # Choose rows that have Toronto in the Borough column

# %%
dfz = dft[dft['Borough'].str.contains('Toronto')].reset_index()
dfz = dfz.drop("index", axis=1)
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)

# %% [markdown]
# # Import necessary libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
# !wget -q -O 'newyork_data.json' https://ibm.box.com/shared/static/fbpwbovar7lf8p5sgddm06cgipa2rxpe.json

# %%
address = 'Toronto, TOR'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))

address1 = 'New York City, NY'

geolocator1 = Nominatim()
location1 = geolocator1.geocode(address1)
latitude1 = location1.latitude
longitude1 = location1.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude1, longitude1))
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# The geograpical coordinate of Toronto are 43.7627912, -79.4064452.
# The geograpical coordinate of New York City are 40.7308619, -73.9871558.

# %% [markdown]
# # Create the maps

# %%
# create map of toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(dfz['Latitude'], dfz['Longitude'], dfz['Borough'], dfz['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create map of Manhattan using latitude and longitude values
map_manhattan = folium.Map(location=[latitude1, longitude1], zoom_start=12)

# add markers to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)  
    
map_manhattan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = '24HOWTVYWO2J0EFCX5H4TVV5A0P2JFCHM4CSQQXBEY5U4250' # your Foursquare ID
CLIENT_SECRET = 'L30RZ1FSOT2ZJTOZBBXGHOYDGG11DQBEKDGC2F0UHBVJXBQC' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 24HOWTVYWO2J0EFCX5H4TVV5A0P2JFCHM4CSQQXBEY5U4250
# CLIENT_SECRET:L30RZ1FSOT2ZJTOZBBXGHOYDGG11DQBEKDGC2F0UHBVJXBQC

# %%
dfz.loc[0, 'Neighborhood']
# Out:
# 'The Beaches'

# %%
manhattan_data.loc[0, 'Neighborhood']
# Out:
# 'Marble Hill'

# %%
neighborhood_latitude = dfz.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = dfz.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = dfz.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of The Beaches are 43.67635739999999, -79.2930312.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

# %%
results = requests.get(url).json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues  = requests.get(url).json()["response"]['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=dfz['Neighborhood'],
                                   latitudes=dfz['Latitude'],
                                   longitudes=dfz['Longitude']
                                  )

# %%
neighborhood_latitude1 = manhattan_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude1 = manhattan_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name1 = manhattan_data.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name1, 
                                                               neighborhood_latitude1, 
                                                               neighborhood_longitude1))
# Out:
# Latitude and longitude values of Marble Hill are 40.87655077879964, -73.91065965862981.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url1 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude1, 
    neighborhood_longitude1, 
    radius, 
    LIMIT)

# %%
results1 = requests.get(url1).json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues1  = requests.get(url1).json()["response"]['groups'][0]['items']
    
nearby_venues1 = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns1 = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues1 =nearby_venues1.loc[:, filtered_columns]

# filter the category for each row
nearby_venues1['venue.categories'] = nearby_venues1.apply(get_category_type, axis=1)

# clean columns
nearby_venues1.columns = [col.split(".")[-1] for col in nearby_venues1.columns]

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
manhattan_venues = getNearbyVenues(names=manhattan_data['Neighborhood'],
                                   latitudes=manhattan_data['Latitude'],
                                   longitudes=manhattan_data['Longitude']
                                  )

# %%
toronto_venues.groupby('Neighborhood').count()

# %%
manhattan_venues.groupby('Neighborhood').count()

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# %%
# one hot encoding
manhattan_onehot = pd.get_dummies(manhattan_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
manhattan_onehot['Neighborhood'] = manhattan_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [manhattan_onehot.columns[-1]] + list(manhattan_onehot.columns[:-1])
manhattan_onehot = manhattan_onehot[fixed_columns]

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
manhattan_grouped = manhattan_onehot.groupby('Neighborhood').mean().reset_index()

# %% [markdown]
# # Defining closest venues

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

# %%
num_top_venues = 5

for hood in manhattan_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = manhattan_grouped[manhattan_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories1 = row.iloc[1:]
    row_categories_sorted1 = row_categories1.sort_values(ascending=False)
    
    return row_categories_sorted1.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 0                              Adelaide,King,Richmond           Coffee Shop
# 1                                         Berczy Park           Coffee Shop
# 2          Brockton,Exhibition Place,Parkdale Village           Coffee Shop
# 3    Business reply mail Processing Centre969 Eastern    Light Rail Station
# 4   CN Tower,Bathurst Quay,Island airport,Harbourf...        Airport Lounge
# 5                          Cabbagetown,St. James Town           Coffee Shop
# 6                                  Central Bay Street           Coffee Shop
# 7             Chinatown,Grange Park,Kensington Market                  Café
# 8                                            Christie         Grocery Store
# 9                                Church and Wellesley   Japanese Restaurant
# 10                      Commerce Court,Victoria Hotel           Coffee Shop
# ...

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = manhattan_grouped['Neighborhood']

for ind in np.arange(manhattan_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(manhattan_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted

# %% [markdown]
# # Start clustering

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 2, 2, 1, 2, 2, 2, 2, 2, 2], dtype=int32)

# %%
toronto_merged = dfz

# add clustering labels
toronto_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
#   Postcode          Borough                   Neighborhood   Latitude  \
# 0      M4E     East Toronto                    The Beaches  43.676357
# 1      M4K     East Toronto    The Danforth West,Riverdale  43.679557
# 2      M4L     East Toronto  The Beaches West,India Bazaar  43.668999
# 3      M4M     East Toronto                Studio District  43.659526
# 4      M4N  Central Toronto                  Lawrence Park  43.728020
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.293031               2  Gym / Fitness Center                   Pub
# 1 -79.352188               2      Greek Restaurant        Ice Cream Shop
# 2 -79.315572               2                  Park        Sandwich Place
# 3 -79.340923               1                  Café           Coffee Shop
# 4 -79.388790               2              Bus Line                  Lake
#
#   3rd Most Common Venue 4th Most Common Venue    5th Most Common Venue  \
# ...

# %%
# set number of clusters
kclusters = 5

manhattan_grouped_clustering = manhattan_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(manhattan_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 1, 0, 0, 0, 0, 0, 4, 1, 3], dtype=int32)

# %%
manhattan_merged = manhattan_data

# add clustering labels
manhattan_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
manhattan_merged = manhattan_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

manhattan_merged.head() # check the last columns!
# Out:
#      Borough        Neighborhood   Latitude  Longitude  Cluster Labels  \
# 0  Manhattan         Marble Hill  40.876551 -73.910660               3
# 1  Manhattan           Chinatown  40.715618 -73.994279               1
# 2  Manhattan  Washington Heights  40.851903 -73.936900               0
# 3  Manhattan              Inwood  40.867684 -73.921210               0
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688               0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0        Discount Store           Coffee Shop           Yoga Studio
# 1    Chinese Restaurant          Cocktail Bar    Dim Sum Restaurant
# 2                  Café                Bakery           Pizza Place
# 3    Mexican Restaurant           Pizza Place                  Café
# 4    Mexican Restaurant           Coffee Shop           Pizza Place
#
#   4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# ...

# %% [markdown]
# # Create cluster map

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create map
map_clusters1 = folium.Map(location=[latitude1, longitude1], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters1)
       
map_clusters1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Toronto clusters

# %%
tor0=toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
tor1=toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
tor2=toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
tor3=toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
tor4=toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]

# %%
tor0

# %%
tor1

# %%
tor01=tor0.merge(tor1, how='outer')
tor012=tor01.merge(tor2, how='outer')
tor0123=tor012.merge(tor3, how='outer')
tor01234=tor0123.merge(tor4, how='outer')
tor01234
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 0    Central Toronto               0           Coffee Shop
# 1   Downtown Toronto               0        Airport Lounge
# 2       East Toronto               1                  Café
# 3   Downtown Toronto               1   Japanese Restaurant
# 4    Central Toronto               1           Music Venue
# 5       West Toronto               1           Coffee Shop
# 6       East Toronto               2  Gym / Fitness Center
# 7       East Toronto               2      Greek Restaurant
# 8       East Toronto               2                  Park
# 9    Central Toronto               2              Bus Line
# 10   Central Toronto               2      Asian Restaurant
# 11   Central Toronto               2   Sporting Goods Shop
# 12   Central Toronto               2        Sandwich Place
# 13   Central Toronto               2                 Trail
# 14   Central Toronto               2                   Pub
# ...

# %% [markdown]
# # Filter the Toronto clusters

# %%
torfin0 = tor01234[~tor01234['1st Most Common Venue'].str.contains('Restaurant')].reset_index()
torfin0 = torfin0.drop("index", axis=1)

torfin1 = torfin0[~torfin0['2nd Most Common Venue'].str.contains('Restaurant')].reset_index()
torfin1 = torfin1.drop("index", axis=1)

torfin2 = torfin1[~torfin1['3rd Most Common Venue'].str.contains('Restaurant')].reset_index()
torfin2 = torfin2.drop("index", axis=1)

torfin3 = torfin2[~torfin2['4th Most Common Venue'].str.contains('Restaurant')].reset_index()
torfin3 = torfin3.drop("index", axis=1)

torfin4 = torfin3[~torfin3['5th Most Common Venue'].str.contains('Restaurant')].reset_index()
torfin4 = torfin4.drop("index", axis=1)

torfin5 = torfin4[~torfin4['6th Most Common Venue'].str.contains('Restaurant')].reset_index()
torfin5 = torfin5.drop("index", axis=1)

torfin6 = torfin5[~torfin5['7th Most Common Venue'].str.contains('Restaurant')].reset_index()
torfin6 = torfin6.drop("index", axis=1)

torfin7 = torfin6[~torfin6['8th Most Common Venue'].str.contains('Restaurant')].reset_index()
torfin7 = torfin7.drop("index", axis=1)

torfin8 = torfin7[~torfin7['9th Most Common Venue'].str.contains('Restaurant')].reset_index()
torfin8 = torfin8.drop("index", axis=1)

torfin9 = torfin8[~torfin8['10th Most Common Venue'].str.contains('Restaurant')].reset_index()
torfin9 = torfin9.drop("index", axis=1)

# %% [markdown]
# ## Check for the frequency of restaurants in these clusters
# ### Determine the clusters that don't have restaurants as the 6th or lower most common venue

# %%
torfin6
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 0  Downtown Toronto               0        Airport Lounge
# 1   Central Toronto               2                 Trail
# 2   Central Toronto               2                   Pub
# 3  Downtown Toronto               2                  Park
# 4  Downtown Toronto               2           Coffee Shop
# 5  Downtown Toronto               2           Coffee Shop
# 6      West Toronto               2           Supermarket
# 7      West Toronto               2           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0       Airport Service      Airport Terminal         Boat or Ferry
# 1            Playground                  Park          Tennis Court
# 2           Coffee Shop    Light Rail Station     Convenience Store
# 3            Playground                 Trail         Women's Store
# 4                Bakery                  Café                  Park
# ...

# %% [markdown]
# ## The clusters above are the locations where someone can build a restaurant with minimum competition from other restaurants

# %% [markdown]
# # Manhattan clusters

# %%
man0=manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 0, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
man1=manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 1, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
man2=manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 2, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
man3=manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 3, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
man4=manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 4, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]

# %%
man0

# %%
man01=man0.merge(man1, how='outer')
man012=man01.merge(man2, how='outer')
man0123=man012.merge(man3, how='outer')
man01234=man0123.merge(man4, how='outer')
man01234
# Out:
#            Neighborhood 1st Most Common Venue    2nd Most Common Venue  \
# 0    Washington Heights                  Café                   Bakery
# 1                Inwood    Mexican Restaurant              Pizza Place
# 2      Hamilton Heights    Mexican Restaurant              Coffee Shop
# 3        Manhattanville    Seafood Restaurant       Mexican Restaurant
# 4        Central Harlem    African Restaurant       Seafood Restaurant
# 5            Lenox Hill    Italian Restaurant         Sushi Restaurant
# 6       Upper West Side    Italian Restaurant                      Bar
# 7               Chelsea           Coffee Shop       Italian Restaurant
# 8          West Village    Italian Restaurant  New American Restaurant
# 9    Financial District           Coffee Shop                    Hotel
# 10                 Noho    Italian Restaurant        French Restaurant
# 11         Civic Center  Gym / Fitness Center                   Bakery
# ...

# %% [markdown]
# # Filter the Manhattan clusters

# %%
manfin0 = man01234[~man01234['1st Most Common Venue'].str.contains('Restaurant')].reset_index()
manfin0 = manfin0.drop("index", axis=1)

manfin1 = manfin0[~manfin0['2nd Most Common Venue'].str.contains('Restaurant')].reset_index()
manfin1 = manfin1.drop("index", axis=1)

manfin2 = manfin1[~manfin1['3rd Most Common Venue'].str.contains('Restaurant')].reset_index()
manfin2 = manfin2.drop("index", axis=1)

manfin3 = manfin2[~manfin2['4th Most Common Venue'].str.contains('Restaurant')].reset_index()
manfin3 = manfin3.drop("index", axis=1)

manfin4 = manfin3[~manfin3['5th Most Common Venue'].str.contains('Restaurant')].reset_index()
manfin4 = manfin4.drop("index", axis=1)

manfin5 = manfin4[~manfin4['6th Most Common Venue'].str.contains('Restaurant')].reset_index()
manfin5 = manfin5.drop("index", axis=1)

manfin6 = manfin5[~manfin5['7th Most Common Venue'].str.contains('Restaurant')].reset_index()
manfin6 = manfin6.drop("index", axis=1)

manfin7 = manfin6[~manfin6['8th Most Common Venue'].str.contains('Restaurant')].reset_index()
manfin7 = manfin7.drop("index", axis=1)

manfin8 = manfin7[~manfin7['9th Most Common Venue'].str.contains('Restaurant')].reset_index()
manfin8 = manfin8.drop("index", axis=1)

manfin9 = manfin8[~manfin8['10th Most Common Venue'].str.contains('Restaurant')].reset_index()
manfin9 = manfin9.drop("index", axis=1)

# %% [markdown]
# ## Check for the frequency of restaurants in these clusters
# ### Determine the clusters that don't have restaurants as the 6th or lower most common venue

# %%
manfin6
# Out:
#       Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0    Carnegie Hill           Pizza Place           Coffee Shop
# 1      Marble Hill        Discount Store           Coffee Shop
# 2          Midtown                 Hotel           Coffee Shop
# 3  Stuyvesant Town                   Bar                  Park
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0        Cosmetics Shop                  Café           Yoga Studio
# 1           Yoga Studio                 Diner       Supplement Shop
# 2            Food Truck            Steakhouse        Clothing Store
# 3         Boat or Ferry   Rental Car Location        Farmers Market
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                   Spa                   Bar             Bookstore
# 1        Tennis Stadium            Shoe Store                  Bank
# 2               Theater                  Park             Bookstore
# ...

# %% [markdown]
# ## The clusters above are the locations where someone can build a restaurant with minimum competition from other restaurants

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## Manhattan has fewer clusters than Toronto which means less opportunities for building a restaurant with the same competition level as Toronto's clusters. Therefore, Toronto is a better choice for a location to build a restaurant
